# %% [markdown]
# black friday dataset eda and feature enginnering
#   cleaning and preparing the data for model training

# %%
import pandas as pd
import numpy as nd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_train=pd.read_csv("train.csv")
df_train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df_test=pd.read_csv("train.csv")
df_test.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
final_df=df_train.merge(df_test)  #we can also use append
final_df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
final_df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
final_df.describe()
# Out:
#        Gender     Occupation  Marital_Status  Product_Category_1  \
# count     0.0  550068.000000   550068.000000       550068.000000
# mean      NaN       8.076707        0.409653            5.404270
# std       NaN       6.522660        0.491770            3.936211
# min       NaN       0.000000        0.000000            1.000000
# 25%       NaN       2.000000        0.000000            1.000000
# 50%       NaN       7.000000        0.000000            5.000000
# 75%       NaN      14.000000        1.000000            8.000000
# max       NaN      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# 25%              5.000000            9.000000    5823.000000
# ...

# %%
final_df.drop(["User_ID"],axis=1,inplace=True)

# %%
final_df.head()
# Out:
#   Product_ID Gender   Age  Occupation City_Category  \
# 0  P00069042      F  0-17          10             A
# 1  P00248942      F  0-17          10             A
# 2  P00087842      F  0-17          10             A
# 3  P00085442      F  0-17          10             A
# 4  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# ...

# %%
final_df.columns
# Out:
# Index(['Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
final_df["Gender"]=final_df["Gender"].map({"F":0,"M":1})#map method is used to maps conditions
final_df.head()
# Out:
#   Product_ID  Gender   Age  Occupation City_Category  \
# 0  P00069042     NaN  0-17          10             A
# 1  P00248942     NaN  0-17          10             A
# 2  P00087842     NaN  0-17          10             A
# 3  P00085442     NaN  0-17          10             A
# 4  P00285442     NaN   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# ...

# %%
final_df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
final_df["Age"]=final_df["Age"].map({"0-17":1,"18-25":2,"26-35":3,'46-50':4,'51-55':5,'36-45':6,'55+':7})

# %%
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
df["Age"]=preprocessing.label_encoder().fit_transform(df["Age"])
df["Age"].unique()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 from sklearn import preprocessing
#       2 label_encoder=preprocessing.LabelEncoder()
#       3 df["Age"]=preprocessing.label_encoder().fit_transform(df["Age"])
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
final_df.head()
# Out:
#    User_ID Product_ID Gender  Age  Occupation City_Category  \
# 0  1000001  P00069042      F  NaN          10             A
# 1  1000001  P00248942      F  NaN          10             A
# 2  1000001  P00087842      F  NaN          10             A
# 3  1000001  P00085442      F  NaN          10             A
# 4  1000002  P00285442      M  NaN          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# ...

# %%
# !pip install sklearn
# Out:
# ...
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [15 lines of output]
#   The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#   rather than 'sklearn' for pip commands.
#
#   Here is how to fix this error in the main use cases:
#   - use 'pip install scikit-learn' rather than 'pip install sklearn'
#   - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#     (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#   - if the 'sklearn' package is used by one of your dependencies,
#     it would be great if you take some time to track which package uses
#     'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#   - as a last resort, set the environment variable
#     SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#   More information is available at
#   https://github.com/scikit-learn/sklearn-pypi-package
#   [end of output]
#
# ...

# %%
df_values=final_df.Purchase.value_counts().values
df_values
# Out:
# array([191, 188, 187, ...,   1,   1,   1], dtype=int64)

# %%
df_lables=final_df.Purchase.value_counts().index
df_lables
# Out:
# Index([ 7011,  7193,  6855,  6891,  7012,  6960,  6879,  7166,  7027,  6868,
#        ...
#        11169, 23851, 11168, 14376,  4918, 23491, 18345,  3372,   855, 21489],
#       dtype='int64', name='Purchase', length=18105)

# %%
plt.bar(df_values[:5],df_lables[:5])
plt.title("pie chart")
plt.show()
