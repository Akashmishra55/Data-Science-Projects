# %%
import pandas as pd

# %%
df=pd.DataFrame({"name":["akash","rohit","virat","gill"],
   "age":[23,28,26,25],
   "city":["mumbai","pune","delhi","gurugram"]})

# %%
df.head()
# Out:
#     name  age      city
# 0  akash   23    mumbai
# 1  rohit   28      pune
# 2  virat   26     delhi
# 3   gill   25  gurugram

# %%
file=pd.read_csv("exl.csv")

# %%
file.head()
# Out:
#    Country Code      name
# 0             2     hello
# 1             6     akash
# 2            10  welldone

# %%
file.describe()
# Out:
#        Country Code
# count           3.0
# mean            6.0
# std             4.0
# min             2.0
# 25%             4.0
# 50%             6.0
# 75%             8.0
# max            10.0

# %%
print(df["name"])
# Out:
# 0    akash
# 1    rohit
# 2    virat
# 3     gill
# Name: name, dtype: object

# %%
print(df[["name","age"]])
# Out:
#     name  age
# 0  akash   23
# 1  rohit   28
# 2  virat   26
# 3   gill   25

# %%
print(df[df["age"]>25])
# Out:
#     name  age   city
# 1  rohit   28   pune
# 2  virat   26  delhi

# %%
print(df.isnull())
# Out:
#     name    age   city
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False

# %%
df.dropna()
# Out:
#     name  age      city
# 0  akash   23    mumbai
# 1  rohit   28      pune
# 2  virat   26     delhi
# 3   gill   25  gurugram

# %%
 df.rename(columns={"name":"team name"})
# Out:
#   team name  age      city
# 0     akash   23    mumbai
# 1     rohit   28      pune
# 2     virat   26     delhi
# 3      gill   25  gurugram

# %%
df["age in 2025"]=df["age"]+[2025 - 2024]

# %%
df["age category"]=df["age"].apply(lambda x:"senior"
if x>25 else "junior")

# %%
grouped_df=df.groupby("name").agg({"age":"mean"})
grouped_df
# Out:
#         age
# name
# akash  23.0
# gill   25.0
# rohit  28.0
# virat  26.0

# %%
merged_df=pd.merge(file,df,on="name")
merged_df
# Out:
#    Country Code   name  age    city
# 0             6  akash   23  mumbai

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("SalesData.csv")

# %%
df.head()
# Out:
#   Retailer country Order method type Product line Product type        Date  \
# 0           France         Telephone     Computer       Laptop  01-01-2016
# 1    United States         Telephone     Computer       Laptop  01-01-2016
# 2           Brazil               Web       Mobile       Iphone  01-01-2016
# 3           Mexico       Sales visit       Mobile      Samsung  01-01-2016
# 4            China               Web       Mobile      Samsung  01-01-2016
#
#    Quantity      Price        Revenue   Unit Cost
# 0        56   1,397.94      78,284.61      772.36
# 1        89   1,397.94    1,24,416.61      724.83
# 2        23     924.64      21,266.70      518.72
# 3        48     750.79      36,037.80      472.25
# 4        77     643.86      49,577.40      388.57

# %%
df.dropna()
# Out:
#       Retailer country Order method type Product line Product type  \
# 0               France         Telephone     Computer       Laptop
# 1        United States         Telephone     Computer       Laptop
# 2               Brazil               Web       Mobile       Iphone
# 3               Mexico       Sales visit       Mobile      Samsung
# 4                China               Web       Mobile      Samsung
# ...                ...               ...          ...          ...
# 72738            China               Web        Books       ebooks
# 72739            Japan               Web        Books       ebooks
# 72740            India               Web        Books       ebooks
# 72741    United States               Web        Books       ebooks
# 72742        Australia       Sales visit        Books       ebooks
#
#              Date  Quantity      Price        Revenue   Unit Cost
# 0      01-01-2016        56   1,397.94      78,284.61      772.36
# ...

# %%
df.describe()
# Out:
#            Quantity
# count  72743.000000
# mean     180.454009
# std      339.118000
# min        1.000000
# 25%       45.000000
# 50%       82.000000
# 75%      179.000000
# max    13575.000000

# %%
df.isnull().sum()
# Out:
# Retailer country     0
# Order method type    0
# Product line         0
# Product type         0
# Date                 0
# Quantity             0
#  Price               0
#  Revenue             0
#  Unit Cost           0
# dtype: int64

# %%
df.head()
# Out:
#   Retailer country Order method type Product line Product type        Date  \
# 0           France         Telephone     Computer       Laptop  01-01-2016
# 1    United States         Telephone     Computer       Laptop  01-01-2016
# 2           Brazil               Web       Mobile       Iphone  01-01-2016
# 3           Mexico       Sales visit       Mobile      Samsung  01-01-2016
# 4            China               Web       Mobile      Samsung  01-01-2016
#
#    Quantity      Price        Revenue   Unit Cost
# 0        56   1,397.94      78,284.61      772.36
# 1        89   1,397.94    1,24,416.61      724.83
# 2        23     924.64      21,266.70      518.72
# 3        48     750.79      36,037.80      472.25
# 4        77     643.86      49,577.40      388.57

# %%
quan=df.Quantity.value_counts().values
country=df..value_counts().values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13644\3988400484.py in ?()
#       1 quan=df.Quantity.value_counts().values
# ----> 2 country=df.Price.value_counts().values
#       3
#
# c:\users\akash mishra\pycharmprojects\essen.tech.prat\venv\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Price'

# %%
plt.plot(country,quan)
plt.xlable("Quantity")
plt.ylable("Price")
plt.title("Distribution of sales")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 plt.plot(country,quan)
#       2 plt.xlable("Quantity")
#       3 plt.ylable("Price")
#
# NameError: name 'country' is not defined
